# %% [markdown]
# <a href="https://colab.research.google.com/github/deepanshuchoudhary448/45-day-of-python/blob/main/DAY13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## pandas

# %%
print("hello")
# Out:
# hello
