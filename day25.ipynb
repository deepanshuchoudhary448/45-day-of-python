# %% [markdown]
# <a href="https://colab.research.google.com/github/deepanshuchoudhary448/45-day-of-python/blob/main/day25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


# Read Dataset
url = "https://raw.githubusercontent.com/deepanshuchoudhary448/45-day-of-python/main/moviesTMBD.csv"
df = pd.read_csv(url)
print(df)

# Scatter Plot
# plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="popularity",
    y="vote_average"
)

plt.title("Popularity vs Vote Average")
plt.xlabel("Popularity")
plt.ylabel("Vote Average")

plt.show()
# Out:
#       Unnamed: 0       id                     title  popularity  adult  \
# 0              0  1007757                   Swapped    327.5134  False
# 1              1      278  The Shawshank Redemption     65.3308  False
# 2              2      238             The Godfather     47.2346  False
# 3              3   687163         Project Hail Mary    422.0199  False
# 4              4      240     The Godfather Part II     27.6763  False
# ...          ...      ...                       ...         ...    ...
# 9975        9975   399173            The Assignment      2.1132  False
# 9976        9976   613377               30 Days Max      1.2237  False
# 9977        9977     8859     Dude, Where's My Car?      2.8157  False
# 9978        9978   313943                    Revolt      1.4022  False
# 9979        9979   277355                    Everly      2.0746  False
#
#      original_language                                           overview  \
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Read Dataset
url = "https://raw.githubusercontent.com/deepanshuchoudhary448/45-day-of-python/main/moviesTMBD.csv"
df = pd.read_csv(url)

# Drop unwanted columns
df.drop(
    ["id", "adult", "original_language", "overview", "release_date","title","Unnamed: 0"],
    axis=1,
    inplace=True
)

print(df.head())


#feature scaling
scaler = StandardScaler()
df[["popularity", "vote_average", "vote_count"]] = scaler.fit_transform(
    df[["popularity", "vote_average", "vote_count"]]
)
print(df)

#split data

x = df[["popularity", "vote_average", "vote_count"]]
y = df["revenue"]
# Out:
#    popularity  vote_average  vote_count
# 0    327.5134         8.987        1320
# 1     65.3308         8.721       30387
# 2     47.2346         8.686       22929
# 3    422.0199         8.621        3950
# 4     27.6763         8.571       13901
#       popularity  vote_average  vote_count
# 0      26.962551      3.489420   -0.235775
# 1       5.064777      3.074444    8.380578
# 2       3.553363      3.019842    6.169797
# 3      34.855836      2.918439    0.543837
# 4       1.919833      2.840436    3.493620
# ...          ...           ...         ...
# 9975   -0.215225     -1.891221   -0.461063
# 9976   -0.289517     -1.950503   -0.506417
# 9977   -0.156552     -1.891221   -0.010488
# 9978   -0.274609     -1.892781   -0.510567
# 9979   -0.218449     -1.894341   -0.453949
#
# [9980 rows x 3 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...
