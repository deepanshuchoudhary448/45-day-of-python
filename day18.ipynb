# %% [markdown]
# <a href="https://colab.research.google.com/github/deepanshuchoudhary448/45-day-of-python/blob/main/day18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Histogram chart

# %%
import matplotlib.pyplot as plt
marks = [40,50,60,70,90,33,50]
plt.hist(marks,bins=2,color = "green")
plt.show()

# %% [markdown]
# # pie chart

# %%
import matplotlib.pyplot as plt
fruits = ["mango","banana","orange","watermalon"]
count = [40,30,15,70]
plt.pie(count,labels = fruits,)
plt.show()

# %%
# pie chart percentage
import matplotlib.pyplot as plt
fruits = ["mango","banana","orange","watermalon"]
count = [40,30,15,70]
color = ["red","yellow","orange","green"]
plt.pie(count,labels = fruits, startangle = 90,autopct="%1.1f%%")
plt.show()

# %%
import matplotlib.pyplot as plt
#first chart
x =[1,2,3,4,5]
y =[10,20,30,40,55]
plt.subplot(2,2,1)

plt.xlabel("x axis")
plt.ylabel("y axis")



#second chart
x1 = ["apple","bnana","orange","watermalon"]
y1 = [40,30,15,70]

plt.subplot(2,2,2)
plt.pie(y1,labels=x1)
plt.xlabel("x1 axis")
plt.ylabel("y1 axis")

# third chart
marks = [40,50,60,70,90,33,50]
plt.hist(marks,bins=2,color = "green")
plt.subplot(2,2,3)

# fourth chart
x1 = ["apple","bnana","orange","watermalon"]
y1 = [40,30,15,70]

plt.subplot(2,2,4)

plt.tight_layout(0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4089/1691516846.py in <cell line: 0>()
#      30 plt.subplot(2,2,4)
#      31
# ---> 32 plt.tight_layout(0)
#      33 plt.show()
#
# TypeError: tight_layout() takes 0 positional arguments but 1 was given

# %%
# subplots
import matplotlib.pyplot as plt
# graph one data
year = [ 2010,2015,2020,2025]
dairy = [ 100, 520,630,400]

# graph two data
year = [1990,2000,2005,2010]
farming = [300,200,250,100]

fig , aux = plt.subplots(1,2)

aux[0].plot(year,dairy) #first col for line chart
aux[0].set_xlabel("year")
aux[0].set_ylabel("dairy")
aux[0].set_title("dairy production graph")


aux[1].plot(year,dairy) #first col for line chart
aux[1].set_xlabel("year")
aux[1].set_ylabel("farmig")
aux[1].set_title("farming production graph")

plt.show()
