# %% [markdown]
# <a href="https://colab.research.google.com/github/deepanshuchoudhary448/45-day-of-python/blob/main/day23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#feature scalling
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

data = {
    'experience': [300,600,900,1500],
    'salary': [1000,1500,2000,3000]
}


#
df = pd.DataFrame(data)
print(df)
#
scaler = StandardScaler()
df['experience'] = scaler.fit_transform(df[['experience']])
print(df)

# split data
x = df['experience']
y = df['salary']

print(x)
print(y)


# Plot graph
plt.figure(figsize=(8, 5))
plt.scatter(x, y, color='blue', s=100)
plt.plot(x, y, color='red')

plt.xlabel('Experience (Scaled)')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.grid(True)

plt.show()
# Out:
#    experience  salary
# 0         300    1000
# 1         600    1500
# 2         900    2000
# 3        1500    3000
#    experience  salary
# 0   -1.183216    1000
# 1   -0.507093    1500
# 2    0.169031    2000
# 3    1.521278    3000
# 0   -1.183216
# 1   -0.507093
# 2    0.169031
# 3    1.521278
# Name: experience, dtype: float64
# 0    1000
# 1    1500
# 2    2000
# 3    3000
# Name: salary, dtype: int64

# %%
# data split traning testing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

data = {
    'experience': [300,600,900,1500],
    'salary': [1000,1500,2000,3000]
}


#
df = pd.DataFrame(data)
print(df)
# split data
x = df['experience']
y = df['salary']

# train test split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=2)
print("x train:",x_train)
print("x test:",x_test)
print("y train:",y_train)
print("y test:",y_test)
# Out:
#    experience  salary
# 0         300    1000
# 1         600    1500
# 2         900    2000
# 3        1500    3000
# x train: 3    1500
# 1     600
# 0     300
# Name: experience, dtype: int64
# x test: 2    900
# Name: experience, dtype: int64
# y train: 3    3000
# 1    1500
# 0    1000
# Name: salary, dtype: int64
# y test: 2    2000
# Name: salary, dtype: int64

# %%
# data split in training and testing

import pandas as pd
from sklearn.model_selection import train_test_split

# dataset url
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/extended_salary_data.csv"

# read csv file
df = pd.read_csv(url)

print(df)

# split data
x = df[["experience"]]   # feature
y = df["salary"]         # target

# train test split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.7, random_state=42
)

print("X Train:")
print(x_train)

print("\nX Test:")
print(x_test)

print("\nY Train:")
print(y_train)

print("\nY Test:")
print(y_test)
# Out:
#      experience  salary
# 0           300    1000
# 1           600    1500
# 2           900    2000
# 3          1500    3000
# 4          1800    3500
# ..          ...     ...
# 99        30300   51000
# 100       30600   51500
# 101       30900   52000
# 102       31200   52500
# 103       31500   53000
#
# [104 rows x 2 columns]
# X Train:
#      experience
# 96        29400
# 41        12900
# 58        18000
# 48        15000
# 89        27300
# 57        17700
# 75        23100
# 32        10200
# 97        29700
# 59        18300
# 63        19500
# 101       30900
# 37        11700
# 29         9300
# 1           600
# 52        16200
# 21         6900
# 2           900
# 23         7500
# 87        26700
# 94        28800
# 74        22800
# 86        26400
# 82        25200
# 20         6600
# 60        18600
# 71        21900
# 14         4800
# 92        28200
# 51        15900
# 102       31200
#
# X Test:
#      experience
# 30         9600
# 65        20100
# ...

# %%
# simple linear reg | prediction
from sklearn.linear_model import LinearRegression


# model fit
model = LinearRegression()
model.fit(x_train,y_train)


# input from user
user = int(input("Enter the Experience: "))


# model prediction
new_data = {
    "experience":[user]
}

df1 = pd.DataFrame(new_data)
print(df1)
pred_data = model.predict(df1)
print(pred_data[0])
# Out:
# Enter the Experience: 234567
#    experience
# 0      234567
# 391445.0
